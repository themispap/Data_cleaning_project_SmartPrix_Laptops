# %%
import pandas as pd

# %%
raw_data=pd.read_csv('/home/themis/projects/Data_cleaning_project_SmartPrix_Laptops/data/smartprix_laptops_unclean.csv')

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   name                 1020 non-null   object
#  1   price                1020 non-null   object
#  2   spec_score           1020 non-null   int64
#  3   votes                1020 non-null   object
#  4   user_rating          1020 non-null   float64
#  5   os                   1020 non-null   object
#  6   utility              1020 non-null   object
#  7   thickness            1019 non-null   object
#  8   weight               910 non-null    object
#  9   warranty             756 non-null    object
#  10  screen_size          1020 non-null   object
#  11  resolution           1020 non-null   object
#  12  ppi                  1020 non-null   object
#  13  battery              957 non-null    object
#  14  screen_feature1      924 non-null    object
#  15  screen_feature2      456 non-null    object
#  16  processor_name       1020 non-null   object
#  17  processor_speed      1020 non-null   object
#  18  no_cores             1020 non-null   object
#  19  caches               1020 non-null   object
#  20  graphics_card        1015 non-null   object
#  21  rom_memory           1015 non-null   object
#  22  internal_memory      980 non-null    object
#  23  port_connection      1020 non-null   object
#  24  wireless_connection  1020 non-null   object
#  25  usb_ports            1019 non-null   object
#  26  hardware_features    1000 non-null   object
# dtypes: float64(1), int64(1), object(25)
# memory usage: 215.3+ KB

# %%
# Extract laptop brand and model from name
raw_data[['brand','name']] = raw_data['name'].str.split(' ',n=1,expand=True)
raw_data[['model','name']] = raw_data['name'].str.split('Laptop',n=1,expand=True)
raw_data[['model','temp']] = raw_data['model'].str.split('Gaming',n=1,expand=True)
raw_data = raw_data.drop(columns=['temp'])

# %%
# Delete the currency symbol from price
raw_data['price']=raw_data['price'].str.replace(',','')
raw_data['price']=raw_data['price'].str.replace('₹','')

# %%
raw_data[['votes','reviews']] = raw_data['votes'].str.split('•',n=1,expand=True)
# Delete the word 'votes' from votes
raw_data['votes']=raw_data['votes'].str.replace(' votes','')
raw_data['votes']=raw_data['votes'].str.replace(',','')
raw_data['reviews']=raw_data['reviews'].str.replace(' reviews','')
raw_data['reviews']=raw_data['reviews'].fillna(0)

# %%
raw_data['os']=raw_data['os'].str.replace('OS: ','')
raw_data['utility']=raw_data['utility'].str.replace('Utility: ','')
raw_data['thickness']=raw_data['thickness'].str.replace('Thickness: ','')
raw_data[['thickness','thicknessV']] = raw_data['thickness'].str.split('mm',n=1,expand=True)
raw_data[['weight','weightV']] = raw_data['weight'].str.split('kg',n=1,expand=True)
# raw_data[['weight','weightV']] = raw_data['weight'].str.split('g',n=1,expand=True)
raw_data['warranty']=raw_data['warranty'].str.replace(' Year Warranty','')
raw_data[['screen_size','screen_sizeV']] = raw_data['screen_size'].str.split('inches',n=1,expand=True)
raw_data[['resolution','resolutionV']] = raw_data['resolution'].str.split('pixels',n=1,expand=True)
raw_data[['ppi','ppiV']] = raw_data['ppi'].str.split('PPI',n=1,expand=True)
raw_data['ppi']=raw_data['ppi'].str.replace('~','')
raw_data[['battery','batteryV']] = raw_data['battery'].str.split('Battery',n=1,expand=True)
raw_data[['battery','cell']] = raw_data['battery'].str.split('Wh',n=1,expand=True)

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 37 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   name                 1013 non-null   object
#  1   price                1020 non-null   object
#  2   spec_score           1020 non-null   int64
#  3   votes                1020 non-null   object
#  4   user_rating          1020 non-null   float64
#  5   os                   1020 non-null   object
#  6   utility              1020 non-null   object
#  7   thickness            1019 non-null   object
#  8   weight               910 non-null    object
#  9   warranty             756 non-null    object
#  10  screen_size          1020 non-null   object
#  11  resolution           1020 non-null   object
#  12  ppi                  1020 non-null   object
#  13  battery              957 non-null    object
#  14  screen_feature1      924 non-null    object
#  15  screen_feature2      456 non-null    object
#  16  processor_name       1020 non-null   object
#  17  processor_speed      1020 non-null   object
#  18  no_cores             1020 non-null   object
#  19  caches               1020 non-null   object
#  20  graphics_card        1015 non-null   object
#  21  rom_memory           1015 non-null   object
#  22  internal_memory      980 non-null    object
#  23  port_connection      1020 non-null   object
#  24  wireless_connection  1020 non-null   object
#  25  usb_ports            1019 non-null   object
#  26  hardware_features    1000 non-null   object
#  27  brand                1020 non-null   object
#  28  model                1020 non-null   object
#  29  reviews              1020 non-null   object
#  30  thicknessV           766 non-null    object
#  31  weightV              753 non-null    object
#  32  screen_sizeV         1020 non-null   object
#  33  resolutionV          1019 non-null   object
#  34  ppiV                 1019 non-null   object
#  35  batteryV             957 non-null    object
#  36  cell                 817 non-null    object
# dtypes: float64(1), int64(1), object(35)
# memory usage: 295.0+ KB

# %%
raw_data.iloc[:,16:]
# Out:
#                       processor_name  \
# 0          5th Gen AMD Ryzen 5 5600H
# 1     14th Gen Intel Core i9 14900HX
# 2      11th Gen Intel Core i3 1115G4
# 3       12th Gen Intel Core i5 1240P
# 4                           Apple M1
# ...                              ...
# 1015    12th Gen Intel Core i5 1235U
# 1016    13th Gen Intel Core i7 1360P
# 1017    13th Gen Intel Core i7 1355U
# 1018    13th Gen Intel Core i5 1340P
# 1019   13th Gen Intel Core i5 13500H
#
#                                         processor_speed  \
# 0          6 x 3.3 GHz (Turbo Speed upto 4.2 GHz) Cores
# 1     8 x 2.2 GHz (Turbo Speed upto 5.8 GHz) Perform...
# 2            2 x 3 GHz (Turbo Speed upto 4.1 GHz) Cores
# 3     4 x 1.7 GHz (Turbo Speed upto 4.4 GHz) Perform...
# 4     4 x (Turbo Speed upto 3.2 GHz) Performance Cor...
# ...                                                 ...
# 1015  2 x 1.3 GHz (Turbo Speed upto 4.4 GHz) Perform...
# 1016  4 x 2.2 GHz (Turbo Speed upto 5 GHz) Performan...
# 1017  2 x (Turbo Speed upto 5 GHz) Performance Cores...
# 1018  4 x 1.9 GHz (Turbo Speed upto 4.6 GHz) Perform...
# 1019  4 x (Turbo Speed upto 4.7 GHz) Performance Cor...
#
#                              no_cores                                 caches  \
# 0               Hexa Core, 12 Threads                            16 MB Cache
# 1     24 Cores (8P + 16E), 32 Threads                            36 MB Cache
# 2                Dual Core, 4 Threads                             6 MB Cache
# 3      12 Cores (4P + 8E), 16 Threads                            12 MB Cache
# 4                 Octa Core (4P + 4E)  Apple M1 Integrated Graphics Graphics
# ...                               ...                                    ...
# 1015   10 Cores (2P + 8E), 12 Threads                            12 MB Cache
# 1016   12 Cores (4P + 8E), 16 Threads                            18 MB Cache
# 1017   10 Cores (2P + 8E), 12 Threads                            12 MB Cache
# 1018   12 Cores (4P + 8E), 16 Threads                            12 MB Cache
# 1019   12 Cores (4P + 8E), 16 Threads                            18 MB Cache
#
#                                          graphics_card  \
# 0            4 GB, AMD Radeon RX 6500M GraphicsLargest
# 1        8 GB, NVIDIA GeForce RTX 4060 GraphicsLargest
# 2                          Intel UHD Graphics Graphics
# 3                      Intel Iris Xe Graphics Graphics
# 4                                8 GB DDR4 RAMSmallest
# ...                                                ...
# 1015                       Intel UHD Graphics Graphics
# 1016  4 GB,  Intel Arc A370M Graphics GraphicsSmallest
# 1017                   Intel Iris Xe Graphics Graphics
# 1018                   Intel Iris Xe Graphics Graphics
# 1019                   Intel Iris Xe Graphics Graphics
#
#                     rom_memory internal_memory  \
# 0         8 GB DDR4 RAMAverage      512 GB SSD
# 1        16 GB DDR5 RAMLargest        1 TB SSD
# 2       8 GB LPDDR4 RAMLargest      512 GB SSD
# 3      16 GB LPDDR5 RAMAverage      512 GB SSD
# 4                   256 GB SSD             NaN
# ...                        ...             ...
# 1015      8 GB DDR4 RAMAverage      512 GB SSD
# 1016     32 GB DDR4 RAMLargest        1 TB SSD
# 1017  16 GB LPDDR4X RAMAverage        1 TB SSD
# 1018  16 GB LPDDR4X RAMAverage      512 GB SSD
# 1019  8 GB LPDDR4X RAMSmallest      512 GB SSD
#
#                                         port_connection   wireless_connection  \
# 0               Ethernet (LAN), HDMI, Multi Card Reader  WiFi, Bluetooth v5.3
# 1     HDMI, Display Port, Thunderbolt, Multi Card Re...  WiFi, Bluetooth v5.3
# 2                                                  HDMI       WiFi, Bluetooth
# 3                  HDMI, Thunderbolt, Multi Card Reader  WiFi, Bluetooth v5.1
# 4                                           Thunderbolt  WiFi, Bluetooth v5.0
# ...                                                 ...                   ...
# 1015            Ethernet (LAN), HDMI, Multi Card Reader  WiFi, Bluetooth v5.1
# 1016                                  HDMI, Thunderbolt  WiFi, Bluetooth v5.3
# 1017                                        Thunderbolt  WiFi, Bluetooth v5.3
# 1018                                               HDMI  WiFi, Bluetooth v5.1
# 1019                                               HDMI  WiFi, Bluetooth v5.1
#
#                                      usb_ports  ...    brand  \
# 0                  2 x USB 3.0, 1 x USB Type-C  ...       HP
# 1     1 x USB 2.0, 3 x USB 3.0, 1 x USB Type-C  ...   Xiaomi
# 2                  3 x USB 3.0, 2 x USB Type-C  ...    Tecno
# 3                  1 x USB 3.0, 1 x USB Type-C  ...  Samsung
# 4                  2 x USB 3.0, 2 x USB Type-C  ...    Apple
# ...                                        ...  ...      ...
# 1015                  1 x USB 2.0, 2 x USB 3.0  ...     Dell
# 1016               1 x USB 3.0, 2 x USB Type-C  ...       HP
# 1017               1 x USB 3.0, 2 x USB Type-C  ...       HP
# 1018  1 x USB 2.0, 1 x USB 3.0, 1 x USB Type-C  ...   Huawei
# 1019  1 x USB 2.0, 1 x USB 3.0, 2 x USB Type-C  ...   Huawei
#
#                                  model reviews  thicknessV  weightV  \
# 0                  Victus 15-fb0157AX        0       Thick    Heavy
# 1                    Redmi G Pro 2024        0       Thick    Heavy
# 2                         Megabook T1        0  Ultra Slim  Average
# 3                 Galaxy Book2 Pro 13       23        Slim     None
# 4            MacBook Air 2020 MGND3HN       43        Slim    Light
# ...                                ...     ...         ...      ...
# 1015         Vostro 3420 D552317WIN9B        0        None     None
# 1016          Spectre x360 16-f2005TX        0       Thick    Heavy
# 1017  Spectre x360 2023 13.5-ef2033TU        0     Average    Light
# 1018                MateBook D14 2023        0        Slim    Light
# 1019                MateBook D16 2023        0     Average  Average
#
#      screen_sizeV resolutionV     ppiV batteryV       cell
# 0         Average     Average  Average     Good  , 3 Cell
# 1           Large        Good     High     Good
# 2         Largest     Average  Average     Good
# 3           Small     Average     High      NaN        NaN
# 4           Small        Good     High     Good
# ...           ...         ...      ...      ...        ...
# 1015        Large     Average     High     Good  , 3 Cell
# 1016      Average        Best     High     Good  , 6 Cell
# 1017        Small        Good     High     Good  , 4 Cell
# 1018        Small        Good     High     Good
# 1019        Large        Good  Average     Good
#
# [1020 rows x 21 columns]
