# %%
# import required packages
import pandas as pd

# %%
# load data
raw_data=pd.read_csv('/home/themis/projects/Data_cleaning_project_SmartPrix_Laptops/data/smartprix_laptops_unclean.csv')

# %%
# data information
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   name                 1020 non-null   object
#  1   price                1020 non-null   object
#  2   spec_score           1020 non-null   int64
#  3   votes                1020 non-null   object
#  4   user_rating          1020 non-null   float64
#  5   os                   1020 non-null   object
#  6   utility              1020 non-null   object
#  7   thickness            1019 non-null   object
#  8   weight               910 non-null    object
#  9   warranty             756 non-null    object
#  10  screen_size          1020 non-null   object
#  11  resolution           1020 non-null   object
#  12  ppi                  1020 non-null   object
#  13  battery              957 non-null    object
#  14  screen_feature1      924 non-null    object
#  15  screen_feature2      456 non-null    object
#  16  processor_name       1020 non-null   object
#  17  processor_speed      1020 non-null   object
#  18  no_cores             1020 non-null   object
#  19  caches               1020 non-null   object
#  20  graphics_card        1015 non-null   object
#  21  rom_memory           1015 non-null   object
#  22  internal_memory      980 non-null    object
#  23  port_connection      1020 non-null   object
#  24  wireless_connection  1020 non-null   object
#  25  usb_ports            1019 non-null   object
#  26  hardware_features    1000 non-null   object
# dtypes: float64(1), int64(1), object(25)
# memory usage: 215.3+ KB

# %%
# Extract laptop brand and model from name
raw_data[['brand','name']] = raw_data['name'].str.split(' ',n=1,expand=True)
raw_data[['model','name']] = raw_data['name'].str.split('Laptop',n=1,expand=True)
raw_data[['model','temp']] = raw_data['model'].str.split('Gaming',n=1,expand=True)
raw_data = raw_data.drop(columns=['temp'])

# %%
# remove the ',' character
raw_data['price']=raw_data['price'].str.replace(',','')
# Delete the currency symbol from price
raw_data['price']=raw_data['price'].str.replace('₹','')
# change dtype to float
raw_data['price'] = raw_data['price'].astype('float64')

# %%
# split the votes column in votes and reviews columns
raw_data[['votes','reviews']] = raw_data['votes'].str.split('•',n=1,expand=True)
# Delete the word 'votes' from votes
raw_data['votes']=raw_data['votes'].str.replace(' votes','')
# remove the ',' character
raw_data['reviews']=raw_data['reviews'].str.replace(',','')
# Delete the word 'votes' from votes
raw_data['reviews']=raw_data['reviews'].str.replace(' reviews','')
# fill nas with 0
raw_data['reviews']=raw_data['reviews'].fillna(0)

# %%
# Delete the word 'OS: ' from os
raw_data['os']=raw_data['os'].str.replace('OS: ','')

# %%
# Delete the word 'Utility: ' from utility
raw_data['utility']=raw_data['utility'].str.replace('Utility: ','')

# %%
# Delete the word 'Thickness: ' from thickness
raw_data['thickness']=raw_data['thickness'].str.replace('Thickness: ','')
# split the thickness column in thickness and thicknessV columns
raw_data[['thickness','thicknessV']] = raw_data['thickness'].str.split('mm',n=1,expand=True)

# %%
# split the weight column in thicweightness and weightV columns
raw_data[['weight','weightV']] = raw_data['weight'].str.split('kg',n=1,expand=True)
# raw_data[['weight','weightV']] = raw_data['weight'].str.split('g',n=1,expand=True)

# %%
# Delete the word ' Year Warranty' from warranty
raw_data['warranty']=raw_data['warranty'].str.replace(' Year Warranty','')

# %%
# split the screen_size column in screen_size and screen_sizeV columns
raw_data[['screen_size','screen_sizeV']] = raw_data['screen_size'].str.split('inches',n=1,expand=True)

# %%
# split the resolution column in resolution and resolutionV columns
raw_data[['resolution','resolutionV']] = raw_data['resolution'].str.split('pixels',n=1,expand=True)

# %%
# split the ppi column in ppi and ppiV columns
raw_data[['ppi','ppiV']] = raw_data['ppi'].str.split('PPI',n=1,expand=True)
# remove the '~' character
raw_data['ppi']=raw_data['ppi'].str.replace('~','')

# %%
# split the battery column in battery and batteryV columns
raw_data[['battery','batteryV']] = raw_data['battery'].str.split('Battery',n=1,expand=True)
# split the battery column in battery and cell columns
raw_data[['battery','cell']] = raw_data['battery'].str.split('Wh',n=1,expand=True)

# %%
# create logical vectors of processors
is_intel = raw_data.processor_name.str.contains(pat = 'Intel', case=False)
is_amd = raw_data.processor_name.str.contains(pat = 'AMD', case=False)
is_apple = raw_data.processor_name.str.contains(pat = 'Apple', case=False)
is_mediatek = raw_data.processor_name.str.contains(pat = 'MediaTek', case=False)
is_other_processor= -is_intel * -is_amd * -is_apple * -is_mediatek

# %%
df_intel_amd=raw_data[is_intel + is_amd]
df_intel_amd[['processor_name','processor_model']] = df_intel_amd['processor_name'].str.rsplit(' ',n=1,expand=True)
df_intel_amd[['processor_name','processor_model']]
# Out:
# /tmp/ipykernel_3538/935384477.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_intel_amd[['processor_name','processor_model']] = df_intel_amd['processor_name'].str.rsplit(' ',n=1,expand=True)
# /tmp/ipykernel_3538/935384477.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_intel_amd[['processor_name','processor_model']] = df_intel_amd['processor_name'].str.rsplit(' ',n=1,expand=True)
#               processor_name processor_model
# 0        5th Gen AMD Ryzen 5           5600H
# 1     14th Gen Intel Core i9         14900HX
# 2     11th Gen Intel Core i3          1115G4
# 3     12th Gen Intel Core i5           1240P
# 5        7th Gen AMD Ryzen 3           7320U
# ...                      ...             ...
# 1015  12th Gen Intel Core i5           1235U
# 1016  13th Gen Intel Core i7           1360P
# 1017  13th Gen Intel Core i7           1355U
# 1018  13th Gen Intel Core i5           1340P
# 1019  13th Gen Intel Core i5          13500H
#
# [994 rows x 2 columns]

# %%
df_apple = raw_data[is_apple]
df_apple[['processor_name','processor_model']] = df_apple['processor_name'].str.split(' ',n=1,expand=True)
df_apple.processor_model
# Out:
# /tmp/ipykernel_3538/1062896352.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_apple[['processor_name','processor_model']] = df_apple['processor_name'].str.split(' ',n=1,expand=True)
# /tmp/ipykernel_3538/1062896352.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_apple[['processor_name','processor_model']] = df_apple['processor_name'].str.split(' ',n=1,expand=True)
# 4          M1
# 9          M2
# 23         M3
# 50         M3
# 51         M3
# 52         M3
# 72     M3 Max
# 73     M3 Pro
# 158        M3
# 159        M3
# 315    M3 Pro
# 316    M3 Pro
# 317        M3
# 318    M3 Max
# 319    M3 Max
# 328        M3
# 811        M2
# Name: processor_model, dtype: object

# %%
df_mediatek = raw_data[is_mediatek]
df_mediatek[['processor_name','processor_model']] = df_mediatek['processor_name'].str.rsplit(' ',n=1,expand=True)
df_mediatek.processor_name
# Out:
# /tmp/ipykernel_3538/124918471.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_mediatek[['processor_name','processor_model']] = df_mediatek['processor_name'].str.rsplit(' ',n=1,expand=True)
# /tmp/ipykernel_3538/124918471.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_mediatek[['processor_name','processor_model']] = df_mediatek['processor_name'].str.rsplit(' ',n=1,expand=True)
# 232    MediaTek Kompanio 520 Kompanio
# 233    MediaTek Kompanio 520 Kompanio
# 242        MediaTek Kompanio Kompanio
# 379                          MediaTek
# 414                          MediaTek
# 640                         Mediatek
# Name: processor_name, dtype: object

# %%
clean_df = pd.concat([df_intel_amd,df_apple,df_mediatek])
# Out:
#                                                   name   price  spec_score  \
# 0     (AMD Ryzen 5 5600H/ 8GB/ 512GB SSD/ Win11/ 4G...   49800          70
# 1     (14th Gen Core i9/ 16GB/ 1TB SSD/ Win11 Home/...  102990          78
# 2       (11th Gen Core i3/ 8GB/ 512GB SSD/ Win11 Home)   23990          56
# 3           (12th Gen Core i5/ 16GB/ 512GB SSD/ Win11)   62990          60
# 5      (AMD Ryzen 3 7320U/ 8GB/ 512GB SSD/ Win11 Home)   26780          55
# ..                                                 ...     ...         ...
# 233   (MediaTek Kompanio 520/ 8GB/ 128GB eMMC/ Chro...   17990          29
# 242   (MediaTek Kompanio 520/ 8GB/ 128GB eMMC/ Chro...   26990          30
# 379         (MediaTek MT8183/ 4GB/ 64B eMMC/ Prime OS)   11990          30
# 414       (MediaTek MT8183/ 4GB/ 128GB eMMC/ Prime OS)   12990          30
# 640                 (Octa Core/ 4GB/ 64GB eMMC/ JioOS)   14701          23
#
#      votes  user_rating                     os                    utility  \
# 0      97           4.3             Windows 11                     Gaming
# 1      71           4.3             Windows 11                     Gaming
# 2     177           4.4             Windows 11                Performance
# 3    1511           4.5             Windows 11               Everyday Use
# 5     205           4.3             Windows 11                Performance
# ..     ...          ...                    ...                        ...
# 233   122           4.2                 Chrome                Performance
# 242   110           4.7                 Chrome               Everyday Use
# 379  1316           4.1  Utility: Everyday Use    Thickness: 19.3 mmThick
# 414   986           4.2  Utility: Everyday Use  Thickness: 19.3 mmAverage
# 640   258           3.4  Utility: Everyday Use              990 gLightest
#
#            thickness           weight warranty  ...  \
# 0              23.5             2.29         1  ...
# 1             23.45              2.7         1  ...
# 2              14.8             1.56         1  ...
# 3              11.2        870 gLight        1  ...
# 5              19.9             1.65         1  ...
# ..               ...              ...      ...  ...
# 233            18.6              1.3         1  ...
# 242     1.45 kgLight  1 Year Warranty      NaN  ...
# 379        1 kgHeavy  1 Year Warranty      NaN  ...
# 414        1 kgLight  1 Year Warranty      NaN  ...
# 640  1 Year Warranty              NaN      NaN  ...
#
#                                         model reviews  thicknessV  weightV  \
# 0                         Victus 15-fb0157AX        0       Thick    Heavy
# 1                           Redmi G Pro 2024        0       Thick    Heavy
# 2                                Megabook T1        0  Ultra Slim  Average
# 3                        Galaxy Book2 Pro 13       23        Slim     None
# 5                         V15 G4 ‎82YU00W7IN       14     Average  Average
# ..                                        ...     ...         ...      ...
# 233  Ideapad Slim 3 Chrome 14M868 82XJ002RHA        2     Average    Light
# 242        Chromebook CM14 CM1402CM2A-EK0085        0        None     None
# 379                      PBMTWIFI11064 Wi-Fi       18        None     None
# 414                                  S Wi-Fi       18        None     None
# 640        JioBook NB1112MM BLU 2023 Netbook        0        None      NaN
#
#     screen_sizeV resolutionV     ppiV batteryV       cell processor_model
# 0        Average     Average  Average     Good  , 3 Cell            5600H
# 1          Large        Good     High     Good                    14900HX
# 2        Largest     Average  Average     Good                     1115G4
# 3          Small     Average     High      NaN        NaN           1240P
# 5        Largest     Average     High      NaN        NaN           7320U
# ..           ...         ...      ...      ...        ...             ...
# 233      Average         Bad      Low     Good                        520
# 242      Average     Average  Average     Good  , 2 Cell              520
# 379        Large        Good     High      NaN        NaN          MT8183
# 414     Smallest     Average  Average      NaN        NaN          MT8183
# 640      Average     Average  Average     Good  , 2 Cell           MT8788
#
# [1017 rows x 38 columns]

# %%
clean_df.price = clean_df.price.astype('float64')
clean_df.votes = clean_df.votes.astype('int64')

# %%
clean_df.thickness
# Out:
# 0                23.5
# 1               23.45
# 2                14.8
# 3                11.2
# 5                19.9
#             ...
# 233              18.6
# 242       1.45 kgLight
# 379          1 kgHeavy
# 414          1 kgLight
# 640    1 Year Warranty
# Name: thickness, Length: 1017, dtype: object

# %%
raw_data.columns
# Out:
# Index(['name', 'price', 'spec_score', 'votes', 'user_rating', 'os', 'utility',
#        'thickness', 'weight', 'warranty', 'screen_size', 'resolution', 'ppi',
#        'battery', 'screen_feature1', 'screen_feature2', 'processor_name',
#        'processor_speed', 'no_cores', 'caches', 'graphics_card', 'rom_memory',
#        'internal_memory', 'port_connection', 'wireless_connection',
#        'usb_ports', 'hardware_features', 'brand', 'model', 'reviews',
#        'thicknessV', 'weightV', 'screen_sizeV', 'resolutionV', 'ppiV',
#        'batteryV', 'cell'],
#       dtype='object')
